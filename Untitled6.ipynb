# %% [markdown]
# <a href="https://colab.research.google.com/github/qnra/MEDICA/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# halo halo tu londyn

# %%
halo halo tu londyn
# Out:
#   File "/tmp/ipykernel_2015/2823468686.py", line 1
#     halo halo tu londyn
#          ^
# SyntaxError: invalid syntax
